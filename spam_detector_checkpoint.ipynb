# %% [markdown]
# <a href="https://colab.research.google.com/github/nabihsabeh85/classification-challenge/blob/main/spam_detector_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spam Detector

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Retrieve the Data
#
# The data is located at [https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv](https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv)
#
# Dataset Source: [UCI Machine Learning Library](https://archive.ics.uci.edu/dataset/94/spambase)
#
# Import the data using Pandas. Display the resulting DataFrame to confirm the import was successful.

# %%
# Import the data
data = pd.read_csv("https://static.bc-edx.com/ai/ail-v-1-0/m13/challenge/spam-data.csv")
data.head()
# Out:
#    word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 0            0.00               0.64           0.64           0.0
# 1            0.21               0.28           0.50           0.0
# 2            0.06               0.00           0.71           0.0
# 3            0.00               0.00           0.00           0.0
# 4            0.00               0.00           0.00           0.0
#
#    word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# 0           0.32            0.00              0.00                0.00
# 1           0.14            0.28              0.21                0.07
# 2           1.23            0.19              0.19                0.12
# 3           0.63            0.00              0.31                0.63
# 4           0.63            0.00              0.31                0.63
#
#    word_freq_order  word_freq_mail  ...  char_freq_;  char_freq_(  \
# 0             0.00            0.00  ...         0.00        0.000
# ...

# %% [markdown]
# ## Predict Model Performance
#
# You will be creating and comparing two models on this data: a Logistic Regression, and a Random Forests Classifier. Before you create, fit, and score the models, make a prediction as to which model you think will perform better. You do not need to be correct!
#
# Write down your prediction in the designated cells in your Jupyter Notebook, and provide justification for your educated guess.

# %% [markdown]
# *Replace the text in this markdown cell with your predictions, and be sure to provide justification for your guess.*

# %% [markdown]
# ## Split the Data into Training and Testing Sets

# %%
# Create the labels set `y` and features DataFrame `X`
X = data.drop("spam", axis=1)
y = data["spam"]

# %%
# Check the balance of the labels variable (`y`) by using the `value_counts` function.
label_balance = y.value_counts()
print(label_balance)
# Out:
# 0    2788
# 1    1813
# Name: spam, dtype: int64

# %%
# Split the data into X_train, X_test, y_train, y_test


# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
X_train
# Out:
#       word_freq_make  word_freq_address  word_freq_all  word_freq_3d  \
# 1173            0.00               0.00           0.00           0.0
# 1954            0.67               0.00           0.00           0.0
# 256             0.00               0.00           1.42           0.0
# 3341            0.00               0.00           0.24           0.0
# 4469            0.00               0.00           0.00           0.0
# ...              ...                ...            ...           ...
# 4426            0.00               0.00           0.00           0.0
# 466             0.00               0.23           0.00           0.0
# 3092            0.00               0.00           0.00           0.0
# 3772            0.00               0.23           0.00           0.0
# 860             0.10               0.00           0.41           0.0
#
#       word_freq_our  word_freq_over  word_freq_remove  word_freq_internet  \
# ...

# %%
y_test
# Out:
# 3683    0
# 4412    0
# 2584    0
# 69      1
# 1844    0
#        ..
# 1912    0
# 1260    1
# 801     1
# 2698    0
# 2095    0
# Name: spam, Length: 1151, dtype: int64

# %% [markdown]
# ## Scale the Features

# %% [markdown]
# Use the `StandardScaler` to scale the features data. Remember that only `X_train` and `X_test` DataFrames should be scaled.

# %%
from sklearn.preprocessing import StandardScaler

# Create the StandardScaler instance
scaler = StandardScaler()

# Fit the Standard Scaler with the training data
scaler.fit(X_train)

# Scale the training and testing features DataFrames
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Fit the Standard Scaler with the training data
from sklearn.linear_model import LogisticRegression

# Create the Logistic Regression model
logistic_model = LogisticRegression()

# Fit the model to the scaled training data
logistic_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
# Scale the training data

# %% [markdown]
# ## Create and Fit a Logistic Regression Model
#
# Create a Logistic Regression model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Logistic Regression model and print the model score

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# 1. Create the Logistic Regression model
logistic_model = LogisticRegression()

# 2. Fit the model to the scaled training data
logistic_model.fit(X_train_scaled, y_train)

# 3. Make predictions on the scaled testing data
y_pred = logistic_model.predict(X_test_scaled)

# 4. Calculate and print the model's accuracy score
accuracy = accuracy_score(y_test, y_pred)
print(f"Logistic Regression Model Accuracy: {accuracy:.4f}")
# Out:
# Logistic Regression Model Accuracy: 0.9227

# %%
# Make and save testing predictions with the saved logistic regression model using the test data

# Review the predictions


# Make predictions with the logistic regression model using the test data
y_test_pred = logistic_model.predict(X_test_scaled)

# Review the first few predictions
print(y_test_pred[:10])
# Out:
# [0 0 0 1 0 1 0 0 0 1]

# %%
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9227

# %% [markdown]
# ## Create and Fit a Random Forest Classifier Model
#
# Create a Random Forest Classifier model, fit it to the training data, make predictions with the testing data, and print the model's accuracy score. You may choose any starting settings you like.

# %%
# Train a Random Forest Classifier model and print the model score
# Make and save testing predictions with the saved logistic regression model using the test data
# Review the predictions
# Calculate the accuracy score by evaluating `y_test` vs. `testing_predictions`.
from sklearn.ensemble import RandomForestClassifier
random_forest_model = RandomForestClassifier()
random_forest_model.fit(X_train_scaled, y_train)
y_test_pred_rf = random_forest_model.predict(X_test_scaled)
accuracy_rf = accuracy_score(y_test, y_test_pred_rf)
print(f"Random Forest Classifier Model Accuracy: {accuracy_rf:.4f}")
# Out:
# Random Forest Classifier Model Accuracy: 0.9574

# %% [markdown]
# ## Evaluate the Models
#
# Which model performed better? How does that compare to your prediction? Write down your results and thoughts in the following markdown cell.

# %% [markdown]
# *Replace the text in this markdown cell with your answers to these questions.*

# %%
## Model Evaluation

# **Logistic Regression Accuracy:** 92.27%
# **Random Forest Classifier Accuracy:** 95.74%

Based on the accuracy scores, the Random Forest Classifier performed better for the spam detection task.

### Reflection

My initial prediction was that the Random Forest Classifier would perform better because of its ability to handle complex and non-linear relationships between features more effectively than logistic regression.
This prediction was based on the understanding that spam detection involves analyzing complex patterns in the data, which random forests are particularly well-suited for, due to their ensemble learning approach.

The outcome aligns with my prediction, demonstrating the Random Forest's strength in managing the intricacies of the dataset and its robustness against overfitting compared to Logistic Regression.
This suggests that for tasks like spam detection, where the relationships between features can be complex and multi-dimensional, ensemble methods like Random Forest can offer significant advantages in terms of model accuracy.

Overall, this comparison highlights the importance of considering the nature of the dataset and the problem when choosing a machine learning model.
While simpler models like Logistic Regression can be effective and more interpretable, complex models like Random Forest may provide higher accuracy in handling tasks with intricate patterns and relationships.
